# %% [markdown]
# <a href="https://colab.research.google.com/github/Ingenjoy/CVX-Optimization/blob/master/convexhull.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from scipy.spatial import ConvexHull

# %%
def Convex():

    imageFile = "image/star.jpg"
    img = cv2.imread(imageFile)
    img1 = img.copy()

    imgray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

    ret, thr = cv2.threshold(imgray, 127, 255,0)

    contours, _ = cv2.findContours(thr, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7,8,7,6,5,4,3,2]
y=[10,11,12,12,10,9,8,8,8,9,10,15,16,17]

# %%
plt.figure(figsize=(10,8))
plt.scatter(x,y)
plt.show()

# %%
points=np.array([list(element) for element in zip(x,y)])
points
# Out:
# array([[ 1, 10],
#        [ 2, 11],
#        [ 3, 12],
#        [ 4, 12],
#        [ 5, 10],
#        [ 6,  9],
#        [ 7,  8],
#        [ 8,  8],
#        [ 7,  8],
#        [ 6,  9],
#        [ 5, 10],
#        [ 4, 15],
#        [ 3, 16],
#        [ 2, 17]])

# %%
hull=ConvexHull(points)

# %%
plt.figure(figsize=(10,8))
plt.scatter(x,y)
plt.grid()

for simplex in hull.simplices:
    plt.plot(points[simplex,0], points[simplex,1],'r--')
    plt.plot(points[simplex,0], points[simplex,1],'ro')
plt.show()
